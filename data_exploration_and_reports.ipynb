# %% [markdown]
# ### 1. Exploratory Data Analysis
# In this section, the dataset is **imported and explored** to understand its structure and content.

# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("Datasets/fact_bookings.csv")
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.booking_platform.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df_bookings.booking_platform.value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
df_date = pd.read_csv("Datasets/dim_date.csv")
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_hotels = pd.read_csv("Datasets/dim_hotels.csv")
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_rooms = pd.read_csv("Datasets/dim_rooms.csv")
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_agg_bookings = pd.read_csv("Datasets/fact_aggregated_bookings.csv")
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# ### 2. Data Cleaning and Transformation
# In this section of the notebook I have **cleaned the dataset** by handling missing values, correcting data inconsistencies,
# and transforming variables where necessary, to prep the data for further analysis.

# %%
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# ...

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings = df_bookings[df_bookings.no_guests>0]

# %%
df_bookings.sort_values(by='revenue_generated', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 128655   Jul272218563RT16        18563     26-07-22      27-07-22
# 69171   Jun162218563RT112        18563     13-06-22      16-06-22
# 128653   Jul272218563RT14        18563     24-07-22      27-07-22
# 9916     May072218558RT13        18558     4/5/2022      7/5/2022
# 9917     May072218558RT14        18558     13-04-22      7/5/2022
# ...                   ...          ...          ...           ...
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 128655      28-07-22        1.0           RT1          logtrip            2.0
# ...

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
avg, std = df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()

# %%
std
# Out:
# np.float64(93040.1549314641)

# %%
avg
# Out:
# np.float64(15378.036937686695)

# %%
higher_limit = avg+3*std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings[df_bookings.revenue_generated<0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated<higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
rev_realised_h_limit = df_bookings.revenue_realized.mean()+3*df_bookings.revenue_realized.std()
rev_realised_h_limit
# Out:
# np.float64(33479.358661845814)

# %%
df_bookings[df_bookings.revenue_realized>rev_realised_h_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
rev_realised_RT4_h_limit = df_bookings[df_bookings.room_category=="RT4"].revenue_realized.mean()+3*df_bookings[df_bookings.room_category=="RT4"].revenue_realized.std()
rev_realised_RT4_h_limit
# Out:
# np.float64(50585.10567100048)

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
# [9200 rows x 5 columns]

# %%
df_agg_bookings["occ_pct"] = round(df_agg_bookings["successful_bookings"]*100/df_agg_bookings["capacity"],2)
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89
# 4    94.74

# %% [markdown]
# ### 3. Ad-hoc Analysis & Insight Generation
# In this section, I generated & exported reports to answer a set of specific questions provided.

# %% [markdown]
# **1. What is the average occupancy rate in each of the room categories?**

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %% [markdown]
# **Convert the RT1, RT2 etc. Print room categories such as Standard, Premium, Elite etc along with average occupancy percentage.**

# %%
df_mrgd_agg_bookings = pd.merge(df_agg_bookings,df_rooms, left_on = "room_category", right_on = "room_id")
df_mrgd_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct room_id    room_class
# ...

# %%
occ_pct_per_room = df_mrgd_agg_bookings.groupby("room_class")["occ_pct"].mean().round(2)
occ_pct_per_room.to_csv('occupancy_rate_per_room.csv')

# %%
df_mrgd_agg_bookings.drop("room_id", axis=1, inplace=True)
df_mrgd_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard
# 4    94.74   Standard

# %% [markdown]
# **2. Print average occupancy rate per city.**

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_mrgd_agg_bookings = pd.merge(df_mrgd_agg_bookings,df_hotels,on="property_id")
df_mrgd_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore
# 3   157.89   Standard   Atliq Grands    Luxury     Mumbai
# 4    94.74   Standard   Atliq Grands    Luxury      Delhi

# %%
df_mrgd_agg_bookings.groupby("city")["occ_pct"].mean().round(2)
# Out:
# city
# Bangalore    56.59
# Delhi        61.61
# Hyderabad    58.14
# Mumbai       57.94
# Name: occ_pct, dtype: float64

# %%
avg_occ_pct_per_city = df_mrgd_agg_bookings.groupby("city")["occ_pct"].mean().round(2)
avg_occ_pct_per_city.to_csv('avg_occ_pct_per_city.csv')

# %% [markdown]
# **3. When was the occupancy better? Weekday or Weekend?**

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_mrgd_agg_bookings = pd.merge(df_mrgd_agg_bookings,df_date,left_on="check_in_date",right_on="date")
df_mrgd_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
# 4        17558     10-May-22           RT1                   11      19.0
#
#    occ_pct room_class property_name  category       city       date  mmm yy  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 1    63.33   Standard    Atliq City  Business  Hyderabad  10-May-22  May 22
# 2    60.00   Standard     Atliq Bay    Luxury  Bangalore  10-May-22  May 22
# 3    53.33   Standard  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 4    57.89   Standard  Atliq Grands    Luxury     Mumbai  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# ...

# %%
df_mrgd_agg_bookings.groupby("day_type")["occ_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %%
avg_occ_pct_by_week = df_mrgd_agg_bookings.groupby("day_type")["occ_pct"].mean().round(2)
avg_occ_pct_by_week.to_csv("avg_occ_pct_by_week.csv")

# %% [markdown]
# **4: In the month of June, what is the occupancy for different cities?**

# %%
df_mrgd_agg_bookings['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %% [markdown]
# **Method 1**

# %%
df_mrgd_agg_bookings[df_mrgd_agg_bookings["mmm yy"]=="Jun 22"].groupby("city")["occ_pct"].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occ_pct, dtype: float64

# %% [markdown]
# **Method 2**

# %%
df_june_22 = df_mrgd_agg_bookings[df_mrgd_agg_bookings["mmm yy"]=="Jun 22"]
df_june_22.head()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
# 2204        16558     10-Jun-22           RT1                   11      19.0
#
#       occ_pct room_class  property_name  category       city       date  \
# 2200    66.67   Standard  Atliq Exotica    Luxury     Mumbai  10-Jun-22
# 2201    63.33   Standard      Atliq Bay    Luxury  Bangalore  10-Jun-22
# 2202    56.67   Standard   Atliq Palace  Business  Bangalore  10-Jun-22
# 2203    47.37   Standard   Atliq Grands    Luxury     Mumbai  10-Jun-22
# 2204    57.89   Standard   Atliq Grands    Luxury      Delhi  10-Jun-22
#
#       mmm yy week no  day_type
# 2200  Jun 22    W 24  weekeday
# ...

# %%
df_june_22.groupby("city")["occ_pct"].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occ_pct, dtype: float64

# %%
avg_occ_pct_by_city_june = df_june_22.groupby("city")["occ_pct"].mean().round(2).sort_values(ascending=False)
avg_occ_pct_by_city_june.to_csv("avg_occ_pct_by_city_jun.csv")

# %% [markdown]
# **5: We got new data for the month of august. Append that to existing data.**

# %%
df_august = pd.read_csv("Datasets/new_data_august.csv")
df_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df_mrgd_agg_bookings.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_class', 'property_name', 'category',
#        'city', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df_mrgd_agg_bookings.shape
# Out:
# (6500, 14)

# %%
latest_df = pd.concat([df_mrgd_agg_bookings,df_august], ignore_index=True, axis=0)
latest_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        17558     31-Jul-22           RT4                    3       6.0
# 6498        19563     31-Jul-22           RT4                    3       6.0
# 6499        17561     31-Jul-22           RT4                    3       4.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class  property_name  category       city       date  \
# ...

# %%
latest_df.to_csv("Aggregated_Booking_Data_Till_Aug.csv")

# %% [markdown]
# **6. Print revenue realized per city.**

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotelbookings = pd.merge(df_bookings,df_hotels,on="property_id")
df_hotelbookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 3  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 4  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_hotelbookings.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %%
realised_rev_per_city = df_hotelbookings.groupby("city")["revenue_realized"].sum()
realised_rev_per_city.to_csv("realised_rev_per_city.csv")

# %% [markdown]
# **7. Print month by month revenue.**

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df_date["date"] = pd.to_datetime(df_date["date"], format="%d-%b-%y")

# %%
df_bookings["check_in_date"] = pd.to_datetime(df_bookings["check_in_date"].str.strip().str.replace(",", ""),format="mixed", dayfirst=True)

# %%
df_booking_dates = pd.merge(df_bookings,df_date,left_on="check_in_date",right_on="date")
df_booking_dates
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22    2022-05-01
# 1        May012216558RT15        16558     27-04-22    2022-05-01
# 2        May012216558RT16        16558     1/5/2022    2022-05-01
# 3        May012216558RT17        16558     28-04-22    2022-05-01
# 4        May012216558RT18        16558     26-04-22    2022-05-01
# ...                   ...          ...          ...           ...
# 134568   Jul312217564RT45        17564     30-07-22    2022-07-31
# 134569   Jul312217564RT46        17564     29-07-22    2022-07-31
# 134570   Jul312217564RT48        17564     30-07-22    2022-07-31
# 134571   Jul312217564RT49        17564     29-07-22    2022-07-31
# 134572  Jul312217564RT410        17564     31-07-22    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_booking_dates.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    572843348
# Jun 22    553925855
# May 22    581767396
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **Print revenue realized per hotel type.**

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_bookings.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 4  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 5  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920
# 5               9100              9100

# %%
df_hotelbookings = pd.merge(df_bookings,df_hotels,on="property_id")
df_hotelbookings.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df_hotelbookings.groupby("property_name")["revenue_realized"].sum().sort_values()
# Out:
# property_name
# Atliq Seasons     66086735
# Atliq Grands     211462134
# Atliq Bay        259996918
# Atliq Blu        260851922
# Atliq City       285798439
# Atliq Palace     304081863
# Atliq Exotica    320258588
# Name: revenue_realized, dtype: int64

# %%
rev_per_hotel = df_hotelbookings.groupby("property_name")["revenue_realized"].sum().sort_values()
rev_per_hotel.to_csv("rev_per_hotel.csv")

# %% [markdown]
# **Print average rating per city.**

# %%
df_hotelbookings.groupby("city")["ratings_given"].mean().round(2).sort_values()
# Out:
# city
# Bangalore    3.41
# Mumbai       3.65
# Hyderabad    3.66
# Delhi        3.78
# Name: ratings_given, dtype: float64

# %%
avg_rating_per_city = df_hotelbookings.groupby("city")["ratings_given"].mean().round(2).sort_values()
avg_rating_per_city.to_csv("avg_rating_per_city.csv")

# %% [markdown]
# **Print a pie chart of revenue realized per booking platform.**

# %%
df_bookings.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 4  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 5  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920
# 5               9100              9100

# %%
df_bookings.groupby("booking_platform")["revenue_realized"].sum()
# Out:
# booking_platform
# direct offline     86374933
# direct online     168948637
# journey           102531334
# logtrip           187494028
# makeyourtrip      340814104
# others            699306762
# tripster          123066801
# Name: revenue_realized, dtype: int64

# %%
rev_realised_per_platform = df_bookings.groupby("booking_platform")["revenue_realized"].sum()
rev_realised_per_platform.to_excel("rev_realised_per_platform.xlsx")

# %%
df_bookings.groupby("booking_platform")["revenue_realized"].sum().plot(kind="pie")
# Out:
# <Axes: ylabel='revenue_realized'>

# %%
import matplotlib.pyplot as plt

df_bookings.groupby("booking_platform")["revenue_realized"].sum().plot(
    kind="pie",
    autopct='%1.1f%%',      # show percentages
    startangle=90,          # rotate the chart
    ylabel=''               # remove y-axis label
)
plt.title("Revenue by Booking Platform")
plt.savefig("booking_pie_chart.png", dpi=300)
plt.show()  # optional — to display the chart
